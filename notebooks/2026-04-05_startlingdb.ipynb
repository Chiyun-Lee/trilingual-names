# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 20)

# %%
doc = pd.read_csv("../data/starling_doc.tsv", sep = "\t")

doc
# Out:
#      Character  Number  Chinese etymology MC description      ZIHUI  \
# 0            一       1  Chinese etymology         臻開三入質影  0001 0707
# 1            乙       2  Chinese etymology         臻開三入質影  0044 0718
# 2            丁       3  Chinese etymology         梗開四平青端  0002 2531
# 3            七       4  Chinese etymology         臻開三入質清  0003 0668
# 4            乃       5  Chinese etymology         蟹開一上海泥  0035 1059
# ...        ...     ...                ...            ...        ...
# 2395         ↔    2599  Chinese etymology         山合三平仙澄  2796 1945
# 2396         x    2601  Chinese etymology         流開一去候影  3371 1574
# 2397         a    2602  Chinese etymology         蟹開二去卦並  4458 1031
# 2398         ]    2605  Chinese etymology         臻合三平諄襌  5573 2177
# 2399         K    2608  Chinese etymology         咸開三去豔來  2966 1818
#
#         Beijing      Jinan     Xi'an    Taiyuan     Hankou   Chengdu  \
# 0          i 11       i 11      i 11     iǝʔ 41       i 12      i 12
# 1           i 2       i 11      i 11     iǝʔ 41       i 12      i 12
# 2        tiŋ 11     tiŋ 11    tiŋ 11      tiŋ 1     tin 11    tin 11
# 3       ćhi 11    ćhi 11   ćhi 11  ćhiǝʔ 41    ćhi 12   ćhi 12
# 4         nai 2       nɛ 3      nɛ 2      nai 2      nai 2     nai 2
# ...         ...        ...       ...        ...        ...       ...
# 2395  c̣huan 12  c̣huã 12  pfhã 12    chuä̃ 1  ćhyan 12  chuan 12
# 2396       ou 3      ŋou 3     ŋou 3      ŋou 3      ŋou 3     ŋǝu 3
# 2397      pai 3       pɛ 3      pɛ 3      pai 3      pai 3     pai 3
# 2398  c̣huǝn 12  c̣huẽ 12  pfhẽ 12     chuŋ 1   ćhyn 12   suǝn 12
# 2399     lian 3     liã 2    liã 2      liɛ 2     nian 3    nian 3
#
#       Yangzhou     Suzhou       Wenzhou  Changsha Shuangfeng  \
# 0        iǝʔ 4    iôʔ 41        iai 41       i 4       i 12
# 1        iǝʔ 4    iôʔ 41        iai 41      ie 4      iɛ 12
# 2       tĩ 11     tin 11        teŋ 11    tin 11     tin 11
# 3     ćhiǝʔ 4  chiôʔ 41       chai 41     chi 4    ćhi 12
# 4         nɛ 2     ne_ 11  na 22; na 11     nai 2       na 2
# ...        ...        ...           ...       ...        ...
# 2395  chuõ 12      zö 12        ʒ́y 12  śyẽ 12    duĩ 12
# 2396     ôɨ 3      öy 11           NaN   ŋôu 31     ŋie 31
# 2397      pɛ 3     ba_ 32         ba 32    pai 32      po 32
# 2398  chuǝn 12     zǝn 12        zoŋ 12   śyn 12    ɣuǝn 12
# 2399    lî̃ 3     lî 32         li 32   niẽ 31    nî̃ 32
#
#                     Nanchang  Meixian Guangzhou                Xiamen  \
# 0                      it 41   jit 41    jat 41  it 41 (lit.); cit 41
# 1                      it 41   jat 41    jyt 41                 it 41
# 2     tin 11 (lit.); tiaŋ 11   tɛn 11   tîŋ 11               tîŋ 11
# 3                   ćhit 41  chit 41   čhat 41        chit 41 (lit.)
# 4                      lai 2   nai 11    nai 22                naĩ 2
# ...                      ...      ...       ...                   ...
# 2395                 chɔn 12  chɔn 12   čhyn 12               tuan 12
# 2396                ńiǝu 31     ɛu 3     au 31          iu 11; au 11
# 2397                 phai 32   phai 3    pāi 32                pai 32
# 2398                  sǝn 31   sun 12   šö_n 12                sun 12
# 2399                 liɛn 32   liam 3    lim 32                liam 2
#
#       Chaozhou    Fuzhou Shanghai Zhongyuan yinyun
# 0        ik 41    eiʔ 41   iîʔ 4             i 43
# 1        ik 41    eiʔ 41   iîʔ 4             i 43
# 2       teŋ 11    tiŋ 11    tiŋ 1           tiǝŋ 1
# 3      chik 41  cheiʔ 41  chîʔ 4           chi 42
# 4       nai 22     nai 2   ne_ 32            nai 2
# ...        ...       ...      ...              ...
# 2395  thueŋ 12   tuɔŋ 12     cö 3         čhyen 12
# 2396     au 31     eu 11     ô 3             ou 1
# 2397  phoĩ 32    pha 31    pe_ 3            pai 3
# 2398    suŋ 12    suŋ 12      NaN              NaN
# 2399   niǝm 21    lieŋ 2   lî 32           liem 2
#
# [2400 rows x 24 columns]

# %%
columns_of_interest = ["Character", "Modern (Beijing) reading", "English meaning"]

bc = pd.read_csv("../data/starling_bigchina.tsv", sep = "\t")

print(
    "Showing what columns have been dropped, in case there is future interest:\n",
    bc[[col for col in bc.columns if col not in columns_of_interest]].head(1).to_dict("records")
)

bc = bc.loc[
    ~bc.Character.isin(["**", "�"]) & (bc.Character.str.len() == 1), columns_of_interest
].dropna().reset_index(drop = True)

bc
# Out:
# Showing what columns have been dropped, in case there is future interest:
#  [{'Preclassic Old Chinese': 'ʔit', 'Classic Old Chinese': 'ʔit', 'Western Han Chinese': 'ʔjǝt', 'Eastern Han Chinese': 'ʔjǝt', 'Early Postclassic Chinese': 'ʔjit', 'Middle Postclassic Chinese': 'ʔjit', 'Late Postclassic Chinese': 'ʔjit', 'Middle Chinese': 'ʔjit', 'Russian meaning[s]': '1) один, единица; 2) единство; одинаковый; объединить; 3) весь; целиком; 4) раз...; как только...; 5) при повторении глагола обозначает однократность действия', 'Comments': 'As in some other cases, Viet. has secondary nasalisation of the initial.', 'Sino-Tibetan etymology': 'Sino-Tibetan etymology', 'Dialectal data': 'Dialectal data', 'Radical': 1, 'Four-angle index': 1, 'Karlgren code': '0394 a-d', 'Go-on': 'iti', 'Kan-on': 'itu', 'Japanese reading': 'ichi;itsu;hitotsu', 'Vietnamese reading': 'nhất', 'Jianchuan Bai': 'ji6, ji5', 'Dali Bai': 'ji6, ji5', 'Bijiang Bai': 'e6', 'Shijing occurrences': '25.1, 25.2, 40.2, 40.3', 'Fanqie': nan, 'Rhyme class': nan, 'Shuowen gloss': nan}]
#      Character Modern (Beijing) reading                       English meaning
# 0            一                      yī                 be one, single, whole
# 1            乙                      yǐ          the 2d of the Heavenly Stems
# 2            丁                    dīng    4th Heavenly Stem; to beat, strike
# 3            七                      qī                              be seven
# 4            乃                     nǎi  then, and then, now; your (possess.)
# ...        ...                      ...                                   ...
# 5367         虌                     biē  an aquatic turtle (Trionyx sinensis)
# 5368         钁                     jué                         big hoe [Han]
# 5369         驩                    huān                             = 歡 q. v.
# 5370         麷                    fēng         grain or buds boiled in water
# 5371         麤                      cū                    gross, coarse [LZ]
#
# [5372 rows x 3 columns]

# %%
import re
import unicodedata

# Pinyin initials (including digraphs)
INITIALS = [
    "zh", "ch", "sh",  # must come before "z", "c", "s"
    "b", "p", "m", "f", "d", "t", "n", "l",
    "g", "k", "h", "j", "q", "x",
    "r", "z", "c", "s", "y", "w"
]

# Vowel mapping with tones
PINYIN_TONE_MAP = {
    "ā": ("a", 1), "á": ("a", 2), "ǎ": ("a", 3), "à": ("a", 4),
    "ē": ("e", 1), "é": ("e", 2), "ě": ("e", 3), "è": ("e", 4),
    "ī": ("i", 1), "í": ("i", 2), "ǐ": ("i", 3), "ì": ("i", 4),
    "ō": ("o", 1), "ó": ("o", 2), "ǒ": ("o", 3), "ò": ("o", 4),
    "ū": ("u", 1), "ú": ("u", 2), "ǔ": ("u", 3), "ù": ("u", 4),
    "ǖ": ("ü", 1), "ǘ": ("ü", 2), "ǚ": ("ü", 3), "ǜ": ("ü", 4),
    # plain vowels (neutral tone)
    "a": ("a", 5), "e": ("e", 5), "i": ("i", 5), "o": ("o", 5),
    "u": ("u", 5), "ü": ("ü", 5),
}

def split_pinyin(pinyin):
    # Normalize to NFC so composed characters (e.g. ī = i + combining macron)
    # match the keys in PINYIN_TONE_MAP
    pinyin = unicodedata.normalize("NFC", pinyin)

    # Step 1: find and normalize tone-marked vowel
    tone = 5
    final_chars = []
    for ch in pinyin:
        if ch in PINYIN_TONE_MAP:
            base, t = PINYIN_TONE_MAP[ch]
            if t != 5:  # don't let a plain vowel overwrite an already-found tone
                tone = t
            final_chars.append(base)
        else:
            final_chars.append(ch)
    pinyin_norm = ''.join(final_chars)

    # Step 2: match initial from the start
    initial = ''
    for init in INITIALS:
        if pinyin_norm.startswith(init):
            initial = init
            break
    final = pinyin_norm[len(initial):]

    return initial, final, tone

bc["decomposed_pinyin"] = bc["Modern (Beijing) reading"].apply(split_pinyin)
bc.Character = bc.Character.str.replace("[", "").str.replace("]", "")

# %%
bc
# Out:
#      Character Modern (Beijing) reading                       English meaning  \
# 0            一                      yī                 be one, single, whole
# 1            乙                      yǐ          the 2d of the Heavenly Stems
# 2            丁                    dīng    4th Heavenly Stem; to beat, strike
# 3            七                      qī                              be seven
# 4            乃                     nǎi  then, and then, now; your (possess.)
# ...        ...                      ...                                   ...
# 5367         虌                     biē  an aquatic turtle (Trionyx sinensis)
# 5368         钁                     jué                         big hoe [Han]
# 5369         驩                    huān                             = 歡 q. v.
# 5370         麷                    fēng         grain or buds boiled in water
# 5371         麤                      cū                    gross, coarse [LZ]
#
#      decomposed_pinyin
# 0            (y, i, 1)
# 1            (y, i, 3)
# 2          (d, ing, 1)
# 3            (q, i, 1)
# 4           (n, ai, 3)
# ...                ...
# 5367        (b, ie, 1)
# 5368        (j, ue, 2)
# 5369       (h, uan, 1)
# 5370       (f, eng, 1)
# 5371         (c, u, 1)
#
# [5372 rows x 4 columns]

# %%
bc.to_pickle("../data/starling_cleaned.pkl.xz")
